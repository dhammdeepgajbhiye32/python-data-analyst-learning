# %%
# Here we will learn how to create a box plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
penguins = sns.load_dataset('penguins')
penguins

sns.set_style('whitegrid')
sns.boxplot(data = penguins , x = 'species', y = 'body_mass_g',hue= 'sex')
plt.title("Box Plot of Body Mass by Penguin Species and Sex")
plt.savefig("010.1.Box_Plot.png")
