# %%
# Creating a Bar Chart with Matplotlib for Bivariant Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a sample dataset
# Create a DataFrame with two numerical columns and a categorical column
data = {
    "Salary" : [25000, 30000, 35000, 29000, 37000, 12000, 29000, 22000, 42000, 45000, 19000, 18000, 26000, 26000, 45000,32450],
    "Deparment" : ["HR", "IT", "Finance", "HR", "IT", "Finance", "HR", "IT", "Finance", "HR", "IT", "Finance", "HR", "IT", "Finance", "HR"],
    "Age" : [25, 30, 35, 29, 37, 22, 29, 32, 40, 45, 19, 28, 26, 31, 38, 27]
}

df = pd.DataFrame(data)
df
# Out:
#     Salary Deparment  Age
# 0    25000        HR   25
# 1    30000        IT   30
# 2    35000   Finance   35
# 3    29000        HR   29
# 4    37000        IT   37
# 5    12000   Finance   22
# 6    29000        HR   29
# 7    22000        IT   32
# 8    42000   Finance   40
# 9    45000        HR   45
# 10   19000        IT   19
# 11   18000   Finance   28
# 12   26000        HR   26
# 13   26000        IT   31
# 14   45000   Finance   38
# 15   32450        HR   27

# %%
# Sorting the DataFrame by Age

from re import S


sort_age = df.sort_values(by="Age")
# Create a bar chart

plt.bar(sort_age["Age"], sort_age["Salary"], color="blue")
plt.title("Salary by Age")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.savefig("009_bar_chart.png")
plt.show()
